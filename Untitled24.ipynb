# %%
import os
import glob
from IPython.display import Image, display

# %%
# !nvidia-smi
# Out:
# Fri Nov 15 05:54:01 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   65C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !mkdir {HOME}/datasets

# %%
HOME = "/content/"

# %%
print(HOME)
# Out:
# /content/

# %%
# !pip install ultralytics==8.0.0

# %%
import ultralytics

# %%
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.4/112.6 GB disk)

# %%
# %cd {HOME}/datasets
# Out:
# /content/datasets

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="PeyrDHp5geBueyl6RFMp")
project = rf.workspace("major-project-vu7ji").project("indian-traffic-signboards-a0gtk")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to INDIAN-TRAFFIC-SIGNBOARDS-1 in yolov8:: 100%|██████████| 6566/6566 [00:01<00:00, 6370.41it/s]

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data=/'content/datasets/INDIANTRAFFICSIGNBOARDS1/data.yaml' epochs=100 imgsz=640
# Out:
# Streaming output truncated to the last 5000 lines.
#      84/100      4.82G     0.5121     0.7592      1.071         45        640:  78% 113/144 [00:53<00:13,  2.24it/s]/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/trainer.py:290: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      84/100      4.82G     0.5119     0.7582      1.071         34        640:  79% 114/144 [00:54<00:17,  1.75it/s]/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/trainer.py:290: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# ...
